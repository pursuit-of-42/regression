# %% [markdown]
# # Importing All packages and Libraries

# %%
from sklearn import datasets #contains all the datasets to work within sklearn package

import pandas as pd #scientific libraries to perform operation on dataset
import numpy as np #scientific libraries to perform operation on dataset

from sklearn.linear_model import LinearRegression,Ridge,Lasso# Importing algorithms to work for prediction

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split # library to divide the data into training set
# and testing set

from sklearn.metrics import mean_squared_error,r2_score #libraries to measure the accuracy and error in prediction

import matplotlib.pyplot as plt # libraries to plot graph and visualize the data distribution 

from sklearn.utils import shuffle #librries to shuffle the data to provide randomization

# %% [markdown]
# # loading the particular dataset from given set of datasets

# %%
boston=datasets.load_boston() #press tab after datasets. to see number of datsets present

# %%
boston.keys() #to get key items that has certain values(assume like title and description)
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
print(boston['DESCR']) # way to determine the value of particular key
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
X=pd.DataFrame(boston.data,columns=boston.feature_names) # Creating a dataframe to perform operations on data 
X
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
X.describe() #getting overall info of data distribution
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
Y=boston.target # assigning the target value or end feature to be predicted

# %%
Y
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %% [markdown]
# # creating new dataframe for single regression i.e how one feature affects target value Y

# %%
X_new=pd.DataFrame(X['LSTAT'])
X_new
# Out:
#      LSTAT
# 0     4.98
# 1     9.14
# 2     4.03
# 3     2.94
# 4     5.33
# 5     5.21
# 6    12.43
# 7    19.15
# 8    29.93
# 9    17.10
# 10   20.45
# 11   13.27
# 12   15.71
# 13    8.26
# 14   10.26
# 15    8.47
# 16    6.58
# 17   14.67
# 18   11.69
# 19   11.28
# 20   21.02
# 21   13.83
# 22   18.72
# 23   19.88
# 24   16.30
# 25   16.51
# 26   14.81
# 27   17.28
# 28   12.80
# 29   11.98
# ..     ...
# 476  18.68
# 477  24.91
# 478  18.03
# 479  13.11
# 480  10.74
# 481   7.74
# 482   7.01
# 483  10.42
# 484  13.34
# 485  10.58
# 486  14.98
# 487  11.45
# 488  18.06
# 489  23.97
# 490  29.68
# 491  18.07
# 492  13.35
# 493  12.01
# 494  13.59
# 495  17.60
# 496  21.14
# 497  14.10
# 498  12.92
# 499  15.10
# 500  14.33
# 501   9.67
# 502   9.08
# 503   5.64
# 504   6.48
# 505   7.88
#
# [506 rows x 1 columns]

# %%
plt.hist(Y)
# Out:
# (array([ 21.,  55.,  82., 154.,  84.,  41.,  30.,   8.,  10.,  21.]),
#  array([ 5. ,  9.5, 14. , 18.5, 23. , 27.5, 32. , 36.5, 41. , 45.5, 50. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Simple Regression
#
# creating a model of our algorithm,
# dividing the data into training and testing set

# %%
model=LinearRegression()
X_train,X_test,Y_train,Y_test = train_test_split(X_new,Y,test_size=0.3,random_state=7)#dividing data into 70% train and 30% test on random seed of 7
X_train
# Out:
#      LSTAT
# 469  14.76
# 141  34.41
# 454  18.71
# 426  15.69
# 362  10.19
# 162   1.92
# 216  13.51
# 324   6.12
# 238   6.36
# 406  23.34
# 81    7.22
# 487  11.45
# 314   9.28
# 187   6.68
# 425  24.39
# 298   4.97
# 179   5.04
# 438  34.02
# 53    8.43
# 395  17.12
# 139  18.46
# 267   7.44
# 278   7.19
# 66   10.24
# 424  17.16
# 259   6.90
# 365   7.12
# 220   9.71
# 99    6.19
# 277   4.16
# ..     ...
# 6    12.43
# 250   5.90
# 311   5.98
# 75    8.94
# 0     4.98
# 428  21.52
# 391  18.76
# 383  24.56
# 432  12.03
# 68   13.09
# 486  14.98
# 167  12.14
# 392  25.68
# 218  17.92
# 42    5.81
# 366  14.00
# 345  10.53
# 72    5.52
# 23   19.88
# 398  30.59
# 185  13.15
# 348   5.99
# 103  13.44
# 407  12.13
# 211  23.98
# 67    8.10
# 502   9.08
# 25   16.51
# 196   4.08
# 175   5.33
#
# [354 rows x 1 columns]

# %%
model.fit(X_train,Y_train)# give data to model for learning
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred=model.predict(X_test)# now asking the model to answer from the learned experience
Y_pred
# Out:
# array([22.26393949, 24.79620654, 22.71245911, 26.94536308, 15.39598272,
#        16.19023623, 22.41344603, 26.21651869, 30.29991611, 18.63840585,
#         6.05182386, 28.72075326, 19.16167875, 20.13347127, 31.75760489,
#        21.24542617, 25.78668738, 30.12237709,  8.77097409, 24.94571308,
#        17.20874954, 29.3935327 , 31.75760489, 17.41432104,  7.07033718,
#        10.56505259, 28.61796752, 28.60862336, 25.89881729, 25.77734322,
#        21.40427687, 28.99173387, 29.33746775, 17.72267828, 31.7108841 ,
#        20.30166613, 21.4883743 , 18.36742524, 22.76852407, 24.02998551,
#        26.43143434, 12.9478131 , 14.7418916 , 27.49666845, 20.92772477,
#        12.16290376, 27.2817528 , 22.82458902, 20.62871169, 22.20787454,
#        27.7583049 , 28.50583761, 25.21669369, 29.72057826, 17.79743155,
#        23.93654393, 19.93724393, 22.31066028, 25.85209649, 22.51623178,
#        21.9649264 , 24.15145958, 22.37606939, 25.98291472, 23.78703738,
# ...

# %%
Y_test #actual answer
# Out:
# array([21.7, 18.5, 22.2, 20.4,  8.8,  8.3, 21.4, 23.6, 23.5, 19. , 10.2,
#        31.6, 18.4, 19.4, 44. , 23.2, 22. , 33.1, 13.2, 21.7, 16.7, 23.9,
#        42.3, 18.5, 14.6,  7.5, 33.4, 22. , 28.1, 24.8, 19.9, 24.8, 28.7,
#        14.1, 43.5, 20.4, 18.3, 13.4, 21. , 22. , 22.6, 13.9, 13.3, 26.5,
#        20. ,  9.5, 21.6, 22.6, 15.6, 23.1, 27.1, 25.2, 15. , 21.9,  9.6,
#        22.7, 18.3, 21.4, 20.5, 21.1, 24.5, 31. , 18.7, 18.7, 22.7, 50. ,
#        16.7, 23. , 20.4, 22.8, 24.8, 10.5, 18.2, 31.5, 23.8, 19.6, 12.7,
#        15.2, 31.2, 14.5, 17.8, 25. , 23. , 50. , 23.7, 25.1, 24.7, 16.8,
#        34.7, 23.3, 50. , 46.7, 43.1, 24.4, 24.1,  6.3, 26.4, 16.3, 17.2,
#        28. , 15.2, 16.6, 20.6, 16.4, 22. , 17.2, 13.5, 23.3, 26.2, 19.7,
#        13.1, 23.9, 18.2, 19.3,  7. , 18.5, 13.8, 33.4, 12.6, 19.6, 20.8,
#        25. , 21.7, 43.8, 13.4, 34.9, 24.5, 26.6, 36.5, 31.1, 22.6, 20.3,
#        18.4, 28.7, 23.1, 17.6, 35.4, 31.6,  8.5, 22.2, 10.4, 22.8, 23.9,
# ...

# %%
model.score(X_train,Y_train) #determinig how good we predicted on training data
# Out:
# 0.5339673849132311

# %%
model.score(X_test,Y_test) #determining how good we predicted on testing data
# Out:
# 0.5677050267960129

# %%
X_test
# Out:
#      LSTAT
# 357  13.27
# 337  10.56
# 327  12.79
# 13    8.26
# 418  20.62
# 403  19.77
# 479  13.11
# 173   9.04
# 65    4.67
# 466  17.15
# 388  30.62
# 227   6.36
# 442  16.59
# 109  15.55
# 256   3.11
# 472  14.36
# 301   9.50
# 303   4.86
# 32   27.71
# 294  10.40
# 476  18.68
# 503   5.64
# 202   3.11
# 245  18.46
# 147  29.53
# 416  25.79
# 306   6.47
# 504   6.48
# 213   9.38
# 289   9.51
# ..     ...
# 221  21.46
# 98    3.57
# 435  23.27
# 40    1.98
# 248   9.52
# 41    4.84
# 264   8.10
# 193   5.03
# 205  10.87
# 79    9.10
# 28   12.80
# 217   9.69
# 347   6.36
# 244  12.50
# 281   4.59
# 57    3.95
# 397  19.92
# 62    6.73
# 380  17.21
# 111  10.16
# 84    9.62
# 242  11.22
# 200   4.45
# 146  16.65
# 188   4.56
# 129  18.34
# 305   8.93
# 96   11.34
# 318  10.36
# 417  26.64
#
# [152 rows x 1 columns]

# %%
plt.scatter(X_test['LSTAT'], Y_test,  color='gray') #plotting the points in form of dots through scatter function
plt.plot(X_test['LSTAT'], Y_pred, color='red', linewidth=2)# determinig the best fit line
plt.show()# function to display after pllot creaion on screen

# %%
model.coef_ # determining coeffiecents(a1,a2,....)
# Out:
# array([-0.93441589])

# %%
model.intercept_# determining intercepts(c)
# Out:
# 34.663638300161935

# %% [markdown]
# # Multiple Regression
#
#    using all the features to determine how the end target is depended on all attributes

# %%
# similar step as explained earlier
model=LinearRegression()
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_pred=model.predict(X_test)
Y_pred
# Out:
# array([28.64896005, 36.49501384, 15.4111932 , 25.40321303, 18.85527988,
#        23.14668944, 17.3921241 , 14.07859899, 23.03692679, 20.59943345,
#        24.82286159, 18.53057049, -6.86543527, 21.80172334, 19.22571177,
#        26.19191985, 20.27733882,  5.61596432, 40.44887974, 17.57695918,
#        27.44319095, 30.1715964 , 10.94055823, 24.02083139, 18.07693812,
#        15.934748  , 23.12614028, 14.56052142, 22.33482544, 19.3257627 ,
#        22.16564973, 25.19476081, 25.31372473, 18.51345025, 16.6223286 ,
#        17.50268505, 30.94992991, 20.19201752, 23.90440431, 24.86975466,
#        13.93767876, 31.82504715, 42.56978796, 17.62323805, 27.01963242,
#        17.19006621, 13.80594006, 26.10356557, 20.31516118, 30.08649576,
#        21.3124053 , 34.15739602, 15.60444981, 26.11247588, 39.31613646,
#        22.99282065, 18.95764781, 33.05555669, 24.85114223, 12.91729352,
#        22.68101452, 30.80336295, 31.63522027, 16.29833689, 21.07379993,
# ...

# %%
model.score(X_train,Y_train)
# Out:
# 0.7434997532004697

# %%
model.score(X_test,Y_test)

# What is this score
# Out:
# 0.711226005748496

# %% [markdown]
# so it is
#
# # 1-mse(predicted model)/mse(average_model)

# %%
predicted=np.mean(Y_test)

# %%
Y_avg_test=[predicted]*len(Y_test)

# %%
1-(mean_squared_error(Y_test,Y_pred)/mean_squared_error(Y_test,Y_avg_test))
# Out:
# 0.711226005748496

# %%
model.coef_
# Out:
# array([-1.33470103e-01,  3.58089136e-02,  4.95226452e-02,  3.11983512e+00,
#        -1.54170609e+01,  4.05719923e+00, -1.08208352e-02, -1.38599824e+00,
#         2.42727340e-01, -8.70223437e-03, -9.10685208e-01,  1.17941159e-02,
#        -5.47113313e-01])

# %%
model.intercept_
# Out:
# 31.631084035694585

# %%
#plot to show how much importance eaach feature has in determinig the target
plt.bar(boston.feature_names,model.coef_)
plt.xticks(rotation= 60)
plt.show()

# %% [markdown]
# # Scalability as a factor

# %%
#standardizing the attributes

model=LinearRegression()
scalar=StandardScaler()
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
X_train_scaled=scalar.fit_transform(X_train)
X_test_scaled=scalar.transform(X_test)

# %%
X_train_scaled.min()
# Out:
# -4.140251946943885

# %%
model.fit(X_train_scaled,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y_new_predicted=model.predict(X_test_scaled)

# %%
model.score(X_train_scaled,Y_train)
# Out:
# 0.7434997532004697

# %%
model.score(X_test_scaled,Y_test)
# Out:
# 0.7112260057484934

# %% [markdown]
# # Regularization and Issues

# %% [markdown]
# #Regularization
#
# b= 10
# a = 5
# error = 20
#
#
# b=10
# a=50  => lead to over-fitting
# error = 19.5
#
#
# Error_Term = Sum of squared errors
#            =  sigma_i (yi - ai -b)^2
#
#
# Error Terms = Sum of squared errors + regularization term * sum of square of corefficients
#          = sigma_i (yi - ai -b)^2+     alpha * sigma_j(a_j^2)
#
#
#
# alpha = 0.01
# b= 10
# a = 5
# error = 20 + 0.01 (5^2)= 20.25
#
#
#
# b=10
# a=50  => lead to over-fitting
# error = 19.5 + 0.01(50^2) = 34.5
#
#
# b=10
# a= 10
# error = 19.8 + 0.01(10^2) = 20.8
#
# b=10
# a= 6
# erorr = 19.85 + 0.01(6^2)= 20.21
# error  -0.15
# reglarization +0.11
#
#
# Ridge regularization or L2 Regularization
#  sigma_i (yi - ai -b)^2+     alpha * sigma_j(a_j^2)
#
# Lasso regularizatior or L1 regularization
# sigma_i (yi - ai -b)^2+     alpha * sigma_j(|a_j|)

# %% [markdown]
# # Ridge Regularization (L2)

# %%
model1=Ridge(alpha=.0001)

model1.fit(X_train,Y_train)
Y_reg=model1.predict(X_test)

# %%
mean_squared_error(Y_test,Y_reg)
# Out:
# 21.517511858968156

# %%
model1.score(X_train,Y_train)
# Out:
# 0.7434997531265819

# %%
model1.score(X_test,Y_test)
# Out:
# 0.7112250981524468

# %% [markdown]
# # Lasso Regularization (L1)

# %%
model2=Lasso(alpha=.000001)
model2.fit(X_train,Y_train)

Y_reg2=model2.predict(X_test)

# %%
+
# Out:
# 0.7112258251516046
